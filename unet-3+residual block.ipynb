# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans22
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  

# neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt


# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

import warnings
warnings.filterwarnings('ignore')

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',   
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE - RED
    2 : 'EDEMA',  # Green
    3 : 'ENHANCING' # original 4 -> converted into 3 later, Yellow
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
#VOLUME_SLICES = 100  
VOLUME_SLICES = 48
VOLUME_START_AT = 22 # first slice of volume that we will include

IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_DEPTH = 48
IMG_CHANNELS = 3

# %%
TRAIN_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
VALIDATION_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/'
# TRAIN_DATASET_PATH = '../input/brats2020-simples/'
# VALIDATION_DATASET_PATH = '../input/brats2020-simples/'

# %%
test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t2.nii').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_image_t1[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_mask[60:-60,:,:]), 90, resize=True), cmap ='gray')

# %%
niimg = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii')
nimask = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii')

fig, axes = plt.subplots(nrows=4, figsize=(30, 40))


nlplt.plot_anat(niimg,
                title='BraTS20_Training_001_flair.nii plot_anat',
                axes=axes[0])

nlplt.plot_epi(niimg,
               title='BraTS20_Training_001_flair.nii plot_epi',
               axes=axes[1])

nlplt.plot_img(niimg,
               title='BraTS20_Training_001_flair.nii plot_img',
               axes=axes[2])

nlplt.plot_roi(nimask, 
               title='BraTS20_Training_001_flair.nii with mask plot_roi',
               bg_img=niimg, 
               axes=axes[3], cmap='Paired')

plt.show()

# %%
import tensorflow as tf
import numpy as np

# Dice Coefficient Metric
def dice_coef(y_true, y_pred, smooth=1e-9):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return tf.reduce_mean(dice)

# Jaccard Index (IoU) Metric
def jaccard_coef(y_true, y_pred, smooth=1e-9):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

# Precision Metric
def precision(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_positives = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    predicted_positives = tf.reduce_sum(y_pred, axis=[1, 2, 3])
    precision = true_positives / (predicted_positives + 1e-9)
    return tf.reduce_mean(precision)

# Sensitivity (Recall) Metric
def sensitivity(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_positives = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    actual_positives = tf.reduce_sum(y_true, axis=[1, 2, 3])
    sensitivity = true_positives / (actual_positives + 1e-9)
    return tf.reduce_mean(sensitivity)

# Specificity Metric
def specificity(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=[1, 2, 3])
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=[1, 2, 3])
    specificity = true_negatives / (true_negatives + false_positives + 1e-9)
    return tf.reduce_mean(specificity)

# Define Per-Class Dice Coefficients with Unique Names
def dice_coef_per_class(class_index, name):
    def dice_coef_class(y_true, y_pred):
        y_true_class = y_true[:, :, :, class_index]
        y_pred_class = y_pred[:, :, :, class_index]
        return dice_coef(y_true_class, y_pred_class)
    
    # Assign a unique name to the metric
    dice_coef_class.__name__ = name
    return dice_coef_class

# BCE + Dice Loss
def bce_dice_loss(y_true, y_pred):
    bce_loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice_loss = 1.0 - dice_coef(y_true, y_pred)
    return bce_loss + dice_loss

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Conv3DTranspose, concatenate, Dropout, Input, Add
from tensorflow.keras.models import Model

def double_conv_block(x, filters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal', dropout_rate=0.1):
    x = Conv3D(filters, kernel_size, activation='relu', padding=padding, kernel_initializer=kernel_initializer)(x)
    x = Dropout(dropout_rate)(x)
    x = Conv3D(filters, kernel_size, activation='relu', padding=padding, kernel_initializer=kernel_initializer)(x)
    x = Dropout(dropout_rate)(x)
    return x

def residual_block(x, filters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal', dropout_rate=0.1):
    conv_out = double_conv_block(x, filters, kernel_size, padding, kernel_initializer, dropout_rate)
    residual = Conv3D(filters, (1, 1, 1), padding=padding, kernel_initializer=kernel_initializer)(x)
    out = Add()([conv_out, residual])
    return out

def build_unet3plus(inputs, ker_init):
    num_classes = 4
    s = inputs

    # Contraction path
    c1 = residual_block(s, 16, kernel_initializer=ker_init, dropout_rate=0.1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = residual_block(p1, 32, kernel_initializer=ker_init, dropout_rate=0.1)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = residual_block(p2, 64, kernel_initializer=ker_init, dropout_rate=0.2)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = residual_block(p3, 128, kernel_initializer=ker_init, dropout_rate=0.2)
    p4 = MaxPooling3D((2, 2, 2))(c4)
     
    c5 = residual_block(p4, 256, kernel_initializer=ker_init, dropout_rate=0.3)
    
    # Expansive path
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = residual_block(u6, 128, kernel_initializer=ker_init, dropout_rate=0.2)
    
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = residual_block(u7, 64, kernel_initializer=ker_init, dropout_rate=0.2)
    
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = residual_block(u8, 32, kernel_initializer=ker_init, dropout_rate=0.1)
    
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = residual_block(u9, 16, kernel_initializer=ker_init, dropout_rate=0.1)
    
    # Single output layer (remove deep supervision)
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
    
    model = Model(inputs=[inputs], outputs=outputs)
    model.summary()
    
    return model

# Define input layer
input_layer = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, 3))  # Adjust based on your data
model = build_unet3plus(input_layer, 'he_normal')

# Compile the model
model.compile(
    loss=bce_dice_loss,  # Use your custom loss function
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core
        dice_coef_per_class(1, "dice_coef_edema"),     # Peritumoral Edema
        dice_coef_per_class(2, "dice_coef_enhancing"), # Enhancing Tumor
        jaccard_coef
    ]
)

print(model.input_shape)
print(model.output_shape)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 128, 128, 48 0
# __________________________________________________________________________________________________
# conv3d_168 (Conv3D)             (None, 128, 128, 48, 1312        input_7[0][0]
# __________________________________________________________________________________________________
# dropout_108 (Dropout)           (None, 128, 128, 48, 0           conv3d_168[0][0]
# __________________________________________________________________________________________________
# conv3d_169 (Conv3D)             (None, 128, 128, 48, 6928        dropout_108[0][0]
# __________________________________________________________________________________________________
# dropout_109 (Dropout)           (None, 128, 128, 48, 0           conv3d_169[0][0]
# __________________________________________________________________________________________________
# conv3d_170 (Conv3D)             (None, 128, 128, 48, 64          input_7[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 128, 128, 48, 0           dropout_109[0][0]
#                                                                  conv3d_170[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_24 (MaxPooling3D) (None, 64, 64, 24, 1 0           add_54[0][0]
# __________________________________________________________________________________________________
# conv3d_171 (Conv3D)             (None, 64, 64, 24, 3 13856       max_pooling3d_24[0][0]
# __________________________________________________________________________________________________
# dropout_110 (Dropout)           (None, 64, 64, 24, 3 0           conv3d_171[0][0]
# __________________________________________________________________________________________________
# conv3d_172 (Conv3D)             (None, 64, 64, 24, 3 27680       dropout_110[0][0]
# __________________________________________________________________________________________________
# dropout_111 (Dropout)           (None, 64, 64, 24, 3 0           conv3d_172[0][0]
# __________________________________________________________________________________________________
# conv3d_173 (Conv3D)             (None, 64, 64, 24, 3 544         max_pooling3d_24[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 64, 64, 24, 3 0           dropout_111[0][0]
#                                                                  conv3d_173[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_25 (MaxPooling3D) (None, 32, 32, 12, 3 0           add_55[0][0]
# __________________________________________________________________________________________________
# conv3d_174 (Conv3D)             (None, 32, 32, 12, 6 55360       max_pooling3d_25[0][0]
# __________________________________________________________________________________________________
# dropout_112 (Dropout)           (None, 32, 32, 12, 6 0           conv3d_174[0][0]
# __________________________________________________________________________________________________
# conv3d_175 (Conv3D)             (None, 32, 32, 12, 6 110656      dropout_112[0][0]
# __________________________________________________________________________________________________
# dropout_113 (Dropout)           (None, 32, 32, 12, 6 0           conv3d_175[0][0]
# __________________________________________________________________________________________________
# conv3d_176 (Conv3D)             (None, 32, 32, 12, 6 2112        max_pooling3d_25[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 32, 32, 12, 6 0           dropout_113[0][0]
#                                                                  conv3d_176[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_26 (MaxPooling3D) (None, 16, 16, 6, 64 0           add_56[0][0]
# __________________________________________________________________________________________________
# conv3d_177 (Conv3D)             (None, 16, 16, 6, 12 221312      max_pooling3d_26[0][0]
# __________________________________________________________________________________________________
# dropout_114 (Dropout)           (None, 16, 16, 6, 12 0           conv3d_177[0][0]
# __________________________________________________________________________________________________
# conv3d_178 (Conv3D)             (None, 16, 16, 6, 12 442496      dropout_114[0][0]
# __________________________________________________________________________________________________
# dropout_115 (Dropout)           (None, 16, 16, 6, 12 0           conv3d_178[0][0]
# __________________________________________________________________________________________________
# conv3d_179 (Conv3D)             (None, 16, 16, 6, 12 8320        max_pooling3d_26[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 16, 16, 6, 12 0           dropout_115[0][0]
#                                                                  conv3d_179[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_27 (MaxPooling3D) (None, 8, 8, 3, 128) 0           add_57[0][0]
# __________________________________________________________________________________________________
# conv3d_180 (Conv3D)             (None, 8, 8, 3, 256) 884992      max_pooling3d_27[0][0]
# __________________________________________________________________________________________________
# dropout_116 (Dropout)           (None, 8, 8, 3, 256) 0           conv3d_180[0][0]
# __________________________________________________________________________________________________
# conv3d_181 (Conv3D)             (None, 8, 8, 3, 256) 1769728     dropout_116[0][0]
# __________________________________________________________________________________________________
# dropout_117 (Dropout)           (None, 8, 8, 3, 256) 0           conv3d_181[0][0]
# __________________________________________________________________________________________________
# conv3d_182 (Conv3D)             (None, 8, 8, 3, 256) 33024       max_pooling3d_27[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 8, 8, 3, 256) 0           dropout_117[0][0]
#                                                                  conv3d_182[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_24 (Conv3DTran (None, 16, 16, 6, 12 262272      add_58[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 16, 16, 6, 25 0           conv3d_transpose_24[0][0]
#                                                                  add_57[0][0]
# __________________________________________________________________________________________________
# conv3d_183 (Conv3D)             (None, 16, 16, 6, 12 884864      concatenate_24[0][0]
# __________________________________________________________________________________________________
# dropout_118 (Dropout)           (None, 16, 16, 6, 12 0           conv3d_183[0][0]
# __________________________________________________________________________________________________
# conv3d_184 (Conv3D)             (None, 16, 16, 6, 12 442496      dropout_118[0][0]
# __________________________________________________________________________________________________
# dropout_119 (Dropout)           (None, 16, 16, 6, 12 0           conv3d_184[0][0]
# __________________________________________________________________________________________________
# conv3d_185 (Conv3D)             (None, 16, 16, 6, 12 32896       concatenate_24[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 16, 16, 6, 12 0           dropout_119[0][0]
#                                                                  conv3d_185[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_25 (Conv3DTran (None, 32, 32, 12, 6 65600       add_59[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 32, 12, 1 0           conv3d_transpose_25[0][0]
#                                                                  add_56[0][0]
# __________________________________________________________________________________________________
# conv3d_186 (Conv3D)             (None, 32, 32, 12, 6 221248      concatenate_25[0][0]
# __________________________________________________________________________________________________
# dropout_120 (Dropout)           (None, 32, 32, 12, 6 0           conv3d_186[0][0]
# __________________________________________________________________________________________________
# conv3d_187 (Conv3D)             (None, 32, 32, 12, 6 110656      dropout_120[0][0]
# __________________________________________________________________________________________________
# dropout_121 (Dropout)           (None, 32, 32, 12, 6 0           conv3d_187[0][0]
# __________________________________________________________________________________________________
# conv3d_188 (Conv3D)             (None, 32, 32, 12, 6 8256        concatenate_25[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 32, 32, 12, 6 0           dropout_121[0][0]
#                                                                  conv3d_188[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_26 (Conv3DTran (None, 64, 64, 24, 3 16416       add_60[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 64, 24, 6 0           conv3d_transpose_26[0][0]
#                                                                  add_55[0][0]
# __________________________________________________________________________________________________
# conv3d_189 (Conv3D)             (None, 64, 64, 24, 3 55328       concatenate_26[0][0]
# __________________________________________________________________________________________________
# dropout_122 (Dropout)           (None, 64, 64, 24, 3 0           conv3d_189[0][0]
# __________________________________________________________________________________________________
# conv3d_190 (Conv3D)             (None, 64, 64, 24, 3 27680       dropout_122[0][0]
# __________________________________________________________________________________________________
# dropout_123 (Dropout)           (None, 64, 64, 24, 3 0           conv3d_190[0][0]
# __________________________________________________________________________________________________
# conv3d_191 (Conv3D)             (None, 64, 64, 24, 3 2080        concatenate_26[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 64, 64, 24, 3 0           dropout_123[0][0]
#                                                                  conv3d_191[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_27 (Conv3DTran (None, 128, 128, 48, 4112        add_61[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 128, 48, 0           conv3d_transpose_27[0][0]
#                                                                  add_54[0][0]
# __________________________________________________________________________________________________
# conv3d_192 (Conv3D)             (None, 128, 128, 48, 13840       concatenate_27[0][0]
# __________________________________________________________________________________________________
# dropout_124 (Dropout)           (None, 128, 128, 48, 0           conv3d_192[0][0]
# __________________________________________________________________________________________________
# conv3d_193 (Conv3D)             (None, 128, 128, 48, 6928        dropout_124[0][0]
# __________________________________________________________________________________________________
# dropout_125 (Dropout)           (None, 128, 128, 48, 0           conv3d_193[0][0]
# __________________________________________________________________________________________________
# conv3d_194 (Conv3D)             (None, 128, 128, 48, 528         concatenate_27[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 128, 128, 48, 0           dropout_125[0][0]
#                                                                  conv3d_194[0][0]
# __________________________________________________________________________________________________
# conv3d_195 (Conv3D)             (None, 128, 128, 48, 68          add_62[0][0]
# ==================================================================================================
# Total params: 5,733,652
# Trainable params: 5,733,652
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (None, 128, 128, 48, 3)
# (None, 128, 128, 48, 4)

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# file BraTS20_Training_355 has ill formatted name for for seg.nii file
#train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')
train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
my_test_ids = ['BraTS20_Training_319', 'BraTS20_Training_252', 'BraTS20_Training_195', 'BraTS20_Training_163', 'BraTS20_Training_213', 'BraTS20_Training_209', 'BraTS20_Training_337', 'BraTS20_Training_058', 'BraTS20_Training_278', 'BraTS20_Training_025', 'BraTS20_Training_143', 'BraTS20_Training_193', 'BraTS20_Training_008', 'BraTS20_Training_024', 'BraTS20_Training_219', 'BraTS20_Training_266', 'BraTS20_Training_282', 'BraTS20_Training_097', 'BraTS20_Training_217', 'BraTS20_Training_153', 'BraTS20_Training_299', 'BraTS20_Training_035', 'BraTS20_Training_349', 'BraTS20_Training_129', 'BraTS20_Training_115', 'BraTS20_Training_002', 'BraTS20_Training_311', 'BraTS20_Training_265', 'BraTS20_Training_231', 'BraTS20_Training_020', 'BraTS20_Training_031', 'BraTS20_Training_036', 'BraTS20_Training_131', 'BraTS20_Training_204', 'BraTS20_Training_347', 'BraTS20_Training_155', 'BraTS20_Training_161', 'BraTS20_Training_041', 'BraTS20_Training_107', 'BraTS20_Training_296', 'BraTS20_Training_047', 'BraTS20_Training_238', 'BraTS20_Training_322', 'BraTS20_Training_016', 'BraTS20_Training_060']

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

# Define the output directory path
output_dir = '/kaggle/working/'

# Function to save IDs to a text file in the output directory
def save_ids_to_file(ids, file_name):
    file_path = os.path.join(output_dir, file_name)
    with open(file_path, 'w') as file:
        for id_ in ids:
            file.write(id_ + '\n')

# Print the number of images in each set
print("Number of images in training set:", len(train_ids))
print("Number of images in validation set:", len(val_ids))
print("Number of images in test set:", len(test_ids))
# Out:
# Number of images in training set: 249
# Number of images in validation set: 74
# Number of images in test set: 45

# %%
def ResizeAndReduceSlices(nib,size,slices,gap):
    imgs = []
    for i in range(128):
        list1 = []
        for j in range(128):
            list2 = []
            for k in range(48):
                list2.append(0)
            list1.append(list2)
        imgs.append(list1)
    imgs = np.array(imgs)
    for i in range(slices):
        imgs[:,:,i] = cv2.resize(nib[:,:,int((i*gap)+20)],(size,size))
    return imgs

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH), batch_size = 1, n_channels = 3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size, *self.dim, self.n_channels)) # shape of (5, 128, 128, 128, 3)
        #y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size, *self.dim)) # shape of (5, 128, 128, 128)
        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata() 

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t2.nii'); 
            t2 = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            #seg=seg.astype(np.uint8)
            #seg[seg==4] = 3

            #temp_combined_images = np.stack([flair, ce, t2], axis=3)
            #temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
            #temp_mask = seg[56:184, 56:184, 13:141]
            
            slice_w = 25

            # (j +VOLUME_SLICES*c) 
            for j in range(VOLUME_SLICES):
                X[c,:,:,j,0] = cv2.resize(flair[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                X[c,:,:,j,1] = cv2.resize(ce[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                X[c,:,:,j,2] = cv2.resize(t2[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));

                #y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
                Y[c,:,:,j] = cv2.resize(seg[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                    
        # Generate masks
        #y[y==4] = 3;
        Y[Y==4] = 3;
        mask = tf.one_hot(Y, 4);
        #Y = tf.image.resize(mask, (IMG_HEIGHT, IMG_WIDTH));
        return X/np.max(X), mask
        #return temp_combined_images/np.max(temp_combined_images), temp_mask
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)
my_test_generator = DataGenerator(my_test_ids )

# %%
print(len(train_ids))
print(len(val_ids))
print(len(test_ids))
print(len(training_generator))
print(len(valid_generator))
print(len(test_generator))
img, mask = test_generator[0]
mask=np.argmax(mask, axis=4)[0,:,:,:]
print(mask.shape)
for n_slice in range(48):
# n_slice = 24
    plt.figure(figsize=(12, 8))
    plt.subplot(231)
    plt.title('Testing Image')
    plt.imshow(img[0,:,:,n_slice,0], cmap='gray')
    plt.subplot(232)
    plt.title('Testing Label')
    plt.imshow(mask[:,:,n_slice])
# Out:
# 249
# 74
# 45
# 249
# 74
# 45
# (128, 128, 48)

# %%
# show number of data for each dir 
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')
    plt.savefig('data2020.png')
    plt.show()
    
showDataLayout()

# %%
history =  model.fit(training_generator,
                    epochs=50,
                    steps_per_epoch=len(train_ids),
                    validation_data = valid_generator
                    )
# Out:
# Epoch 1/50
# 249/249 [==============================] - 108s 419ms/step - loss: 0.7844 - accuracy: 0.9797 - mean_io_u_24: 0.8190 - dice_coef: 0.2671 - precision: 0.3093 - sensitivity: 0.2506 - specificity: 0.7679 - dice_coef_necrotic: 0.9777 - dice_coef_edema: 0.9847 - dice_coef_enhancing: 0.9846 - jaccard_coef: 0.2621 - val_loss: 0.7448 - val_accuracy: 0.9869 - val_mean_io_u_24: 0.8300 - val_dice_coef: 0.2851 - val_precision: 0.3273 - val_sensitivity: 0.2702 - val_specificity: 0.8180 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2747
# Epoch 2/50
# 249/249 [==============================] - 98s 395ms/step - loss: 0.7348 - accuracy: 0.9863 - mean_io_u_24: 0.8594 - dice_coef: 0.2891 - precision: 0.3578 - sensitivity: 0.2680 - specificity: 0.8072 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.2789 - val_loss: 0.7418 - val_accuracy: 0.9875 - val_mean_io_u_24: 0.8948 - val_dice_coef: 0.2774 - val_precision: 0.3261 - val_sensitivity: 0.2611 - val_specificity: 0.8044 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2699
# Epoch 3/50
# 249/249 [==============================] - 100s 400ms/step - loss: 0.7208 - accuracy: 0.9868 - mean_io_u_24: 0.8566 - dice_coef: 0.3014 - precision: 0.4041 - sensitivity: 0.2798 - specificity: 0.8245 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2869 - val_loss: 0.7420 - val_accuracy: 0.9876 - val_mean_io_u_24: 0.8614 - val_dice_coef: 0.2749 - val_precision: 0.3512 - val_sensitivity: 0.2585 - val_specificity: 0.8130 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2684
# Epoch 4/50
# 249/249 [==============================] - 89s 358ms/step - loss: 0.7545 - accuracy: 0.9856 - mean_io_u_24: 0.8254 - dice_coef: 0.2751 - precision: 0.3072 - sensitivity: 0.2553 - specificity: 0.7724 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2705 - val_loss: 0.7574 - val_accuracy: 0.9870 - val_mean_io_u_24: 0.8620 - val_dice_coef: 0.2655 - val_precision: 0.2605 - val_sensitivity: 0.2529 - val_specificity: 0.7759 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2629
# Epoch 5/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.7405 - accuracy: 0.9862 - mean_io_u_24: 0.8570 - dice_coef: 0.2818 - precision: 0.3055 - sensitivity: 0.2598 - specificity: 0.7898 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2758 - val_loss: 0.7571 - val_accuracy: 0.9870 - val_mean_io_u_24: 0.9027 - val_dice_coef: 0.2654 - val_precision: 0.2703 - val_sensitivity: 0.2521 - val_specificity: 0.7703 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2625
# Epoch 6/50
# 249/249 [==============================] - 88s 352ms/step - loss: 0.7259 - accuracy: 0.9869 - mean_io_u_24: 0.8656 - dice_coef: 0.2938 - precision: 0.4054 - sensitivity: 0.2679 - specificity: 0.8159 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2829 - val_loss: 0.7275 - val_accuracy: 0.9875 - val_mean_io_u_24: 0.8848 - val_dice_coef: 0.2897 - val_precision: 0.4133 - val_sensitivity: 0.2796 - val_specificity: 0.8334 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2757
# Epoch 7/50
# 249/249 [==============================] - 88s 355ms/step - loss: 0.7012 - accuracy: 0.9875 - mean_io_u_24: 0.8754 - dice_coef: 0.3177 - precision: 0.5037 - sensitivity: 0.2916 - specificity: 0.8455 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2976 - val_loss: 0.7357 - val_accuracy: 0.9875 - val_mean_io_u_24: 0.8427 - val_dice_coef: 0.2845 - val_precision: 0.4091 - val_sensitivity: 0.2727 - val_specificity: 0.8104 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2719
# Epoch 8/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.6857 - accuracy: 0.9876 - mean_io_u_24: 0.8303 - dice_coef: 0.3328 - precision: 0.5068 - sensitivity: 0.3078 - specificity: 0.8460 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3066 - val_loss: 0.7202 - val_accuracy: 0.9882 - val_mean_io_u_24: 0.9334 - val_dice_coef: 0.3006 - val_precision: 0.4188 - val_sensitivity: 0.2808 - val_specificity: 0.8101 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2841
# Epoch 9/50
# 249/249 [==============================] - 89s 357ms/step - loss: 0.6578 - accuracy: 0.9883 - mean_io_u_24: 0.8779 - dice_coef: 0.3587 - precision: 0.5595 - sensitivity: 0.3241 - specificity: 0.8629 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3253 - val_loss: 0.6499 - val_accuracy: 0.9878 - val_mean_io_u_24: 0.8651 - val_dice_coef: 0.3661 - val_precision: 0.5141 - val_sensitivity: 0.3785 - val_specificity: 0.8947 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3289
# Epoch 10/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6445 - accuracy: 0.9885 - mean_io_u_24: 0.8767 - dice_coef: 0.3714 - precision: 0.5801 - sensitivity: 0.3387 - specificity: 0.8722 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3339 - val_loss: 0.6240 - val_accuracy: 0.9895 - val_mean_io_u_24: 0.8928 - val_dice_coef: 0.3904 - val_precision: 0.5466 - val_sensitivity: 0.3751 - val_specificity: 0.8846 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3480
# Epoch 11/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6890 - accuracy: 0.9869 - mean_io_u_24: 0.8474 - dice_coef: 0.3335 - precision: 0.4592 - sensitivity: 0.3045 - specificity: 0.8338 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3100 - val_loss: 0.7288 - val_accuracy: 0.9876 - val_mean_io_u_24: 0.8875 - val_dice_coef: 0.2913 - val_precision: 0.3604 - val_sensitivity: 0.2755 - val_specificity: 0.8122 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2792
# Epoch 12/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6978 - accuracy: 0.9874 - mean_io_u_24: 0.8722 - dice_coef: 0.3215 - precision: 0.4722 - sensitivity: 0.2939 - specificity: 0.8422 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3019 - val_loss: 0.7458 - val_accuracy: 0.9865 - val_mean_io_u_24: 0.8935 - val_dice_coef: 0.2749 - val_precision: 0.3361 - val_sensitivity: 0.2600 - val_specificity: 0.7839 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2684
# Epoch 13/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6901 - accuracy: 0.9874 - mean_io_u_24: 0.8648 - dice_coef: 0.3286 - precision: 0.5136 - sensitivity: 0.2999 - specificity: 0.8357 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3040 - val_loss: 0.7235 - val_accuracy: 0.9866 - val_mean_io_u_24: 0.8651 - val_dice_coef: 0.2968 - val_precision: 0.4078 - val_sensitivity: 0.2873 - val_specificity: 0.8236 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 0.9999 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.2811
# Epoch 14/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6930 - accuracy: 0.9875 - mean_io_u_24: 0.8608 - dice_coef: 0.3272 - precision: 0.5052 - sensitivity: 0.2990 - specificity: 0.8300 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3043 - val_loss: 0.6839 - val_accuracy: 0.9881 - val_mean_io_u_24: 0.8676 - val_dice_coef: 0.3346 - val_precision: 0.5112 - val_sensitivity: 0.3133 - val_specificity: 0.8417 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3052
# Epoch 15/50
# 249/249 [==============================] - 88s 355ms/step - loss: 0.6587 - accuracy: 0.9880 - mean_io_u_24: 0.8819 - dice_coef: 0.3578 - precision: 0.5609 - sensitivity: 0.3238 - specificity: 0.8537 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3242 - val_loss: 0.6592 - val_accuracy: 0.9894 - val_mean_io_u_24: 0.8771 - val_dice_coef: 0.3549 - val_precision: 0.5328 - val_sensitivity: 0.3355 - val_specificity: 0.8771 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3209
# Epoch 16/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.6326 - accuracy: 0.9884 - mean_io_u_24: 0.8863 - dice_coef: 0.3836 - precision: 0.5885 - sensitivity: 0.3512 - specificity: 0.8707 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3439 - val_loss: 0.7262 - val_accuracy: 0.9879 - val_mean_io_u_24: 0.8704 - val_dice_coef: 0.2928 - val_precision: 0.4282 - val_sensitivity: 0.2781 - val_specificity: 0.8069 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2789
# Epoch 17/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6564 - accuracy: 0.9883 - mean_io_u_24: 0.8805 - dice_coef: 0.3596 - precision: 0.5697 - sensitivity: 0.3275 - specificity: 0.8616 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3235 - val_loss: 0.6389 - val_accuracy: 0.9902 - val_mean_io_u_24: 0.8687 - val_dice_coef: 0.3745 - val_precision: 0.5546 - val_sensitivity: 0.3458 - val_specificity: 0.8928 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3332
# Epoch 18/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6358 - accuracy: 0.9887 - mean_io_u_24: 0.8836 - dice_coef: 0.3796 - precision: 0.6003 - sensitivity: 0.3457 - specificity: 0.8745 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3382 - val_loss: 0.6463 - val_accuracy: 0.9894 - val_mean_io_u_24: 0.8834 - val_dice_coef: 0.3685 - val_precision: 0.5352 - val_sensitivity: 0.3394 - val_specificity: 0.8493 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3301
# Epoch 19/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6154 - accuracy: 0.9892 - mean_io_u_24: 0.8871 - dice_coef: 0.3997 - precision: 0.6104 - sensitivity: 0.3635 - specificity: 0.8817 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3535 - val_loss: 0.6460 - val_accuracy: 0.9894 - val_mean_io_u_24: 0.8838 - val_dice_coef: 0.3701 - val_precision: 0.5576 - val_sensitivity: 0.3393 - val_specificity: 0.8479 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3328
# Epoch 20/50
# 249/249 [==============================] - 88s 352ms/step - loss: 0.6227 - accuracy: 0.9889 - mean_io_u_24: 0.8746 - dice_coef: 0.3934 - precision: 0.6212 - sensitivity: 0.3565 - specificity: 0.8774 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3493 - val_loss: 0.6852 - val_accuracy: 0.9879 - val_mean_io_u_24: 0.8645 - val_dice_coef: 0.3321 - val_precision: 0.4928 - val_sensitivity: 0.3180 - val_specificity: 0.8372 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3044
# Epoch 21/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.5878 - accuracy: 0.9892 - mean_io_u_24: 0.8698 - dice_coef: 0.4268 - precision: 0.6458 - sensitivity: 0.3846 - specificity: 0.8850 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3734 - val_loss: 0.5849 - val_accuracy: 0.9907 - val_mean_io_u_24: 0.8830 - val_dice_coef: 0.4276 - val_precision: 0.5903 - val_sensitivity: 0.4116 - val_specificity: 0.9012 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3764
# Epoch 22/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.5650 - accuracy: 0.9899 - mean_io_u_24: 0.8925 - dice_coef: 0.4483 - precision: 0.6465 - sensitivity: 0.4149 - specificity: 0.9034 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3909 - val_loss: 0.5421 - val_accuracy: 0.9912 - val_mean_io_u_24: 0.8951 - val_dice_coef: 0.4697 - val_precision: 0.6457 - val_sensitivity: 0.4553 - val_specificity: 0.9057 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4069
# Epoch 23/50
# 249/249 [==============================] - 88s 351ms/step - loss: 0.5399 - accuracy: 0.9905 - mean_io_u_24: 0.9055 - dice_coef: 0.4724 - precision: 0.6567 - sensitivity: 0.4412 - specificity: 0.9152 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4085 - val_loss: 0.5920 - val_accuracy: 0.9905 - val_mean_io_u_24: 0.9116 - val_dice_coef: 0.4248 - val_precision: 0.5738 - val_sensitivity: 0.4029 - val_specificity: 0.8786 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3754
# Epoch 24/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5403 - accuracy: 0.9903 - mean_io_u_24: 0.8975 - dice_coef: 0.4724 - precision: 0.6567 - sensitivity: 0.4460 - specificity: 0.9108 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4089 - val_loss: 0.5642 - val_accuracy: 0.9909 - val_mean_io_u_24: 0.9153 - val_dice_coef: 0.4484 - val_precision: 0.6184 - val_sensitivity: 0.4331 - val_specificity: 0.8850 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3941
# Epoch 25/50
# 249/249 [==============================] - 88s 355ms/step - loss: 0.5252 - accuracy: 0.9908 - mean_io_u_24: 0.9107 - dice_coef: 0.4866 - precision: 0.6671 - sensitivity: 0.4567 - specificity: 0.9192 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4192 - val_loss: 0.5487 - val_accuracy: 0.9914 - val_mean_io_u_24: 0.9076 - val_dice_coef: 0.4625 - val_precision: 0.6370 - val_sensitivity: 0.4353 - val_specificity: 0.9017 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4045
# Epoch 26/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5449 - accuracy: 0.9899 - mean_io_u_24: 0.8900 - dice_coef: 0.4695 - precision: 0.6463 - sensitivity: 0.4395 - specificity: 0.9025 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4082 - val_loss: 0.5652 - val_accuracy: 0.9905 - val_mean_io_u_24: 0.8787 - val_dice_coef: 0.4476 - val_precision: 0.6138 - val_sensitivity: 0.4208 - val_specificity: 0.8948 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3914
# Epoch 27/50
# 249/249 [==============================] - 88s 352ms/step - loss: 0.6058 - accuracy: 0.9889 - mean_io_u_24: 0.8774 - dice_coef: 0.4108 - precision: 0.6005 - sensitivity: 0.3795 - specificity: 0.8750 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3629 - val_loss: 0.6280 - val_accuracy: 0.9896 - val_mean_io_u_24: 0.9042 - val_dice_coef: 0.3883 - val_precision: 0.5930 - val_sensitivity: 0.3483 - val_specificity: 0.8612 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3452
# Epoch 28/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.6929 - accuracy: 0.9868 - mean_io_u_24: 0.8674 - dice_coef: 0.3297 - precision: 0.4657 - sensitivity: 0.3062 - specificity: 0.8070 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9995 - jaccard_coef: 0.3055 - val_loss: 0.7244 - val_accuracy: 0.9878 - val_mean_io_u_24: 0.8857 - val_dice_coef: 0.2948 - val_precision: 0.3761 - val_sensitivity: 0.2824 - val_specificity: 0.7969 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2810
# Epoch 29/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6125 - accuracy: 0.9887 - mean_io_u_24: 0.8892 - dice_coef: 0.4028 - precision: 0.5886 - sensitivity: 0.3653 - specificity: 0.8683 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3574 - val_loss: 0.5963 - val_accuracy: 0.9904 - val_mean_io_u_24: 0.9020 - val_dice_coef: 0.4166 - val_precision: 0.5537 - val_sensitivity: 0.3991 - val_specificity: 0.8870 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3691
# Epoch 30/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.5651 - accuracy: 0.9898 - mean_io_u_24: 0.8900 - dice_coef: 0.4486 - precision: 0.6438 - sensitivity: 0.4108 - specificity: 0.8911 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3914 - val_loss: 0.5577 - val_accuracy: 0.9909 - val_mean_io_u_24: 0.8793 - val_dice_coef: 0.4553 - val_precision: 0.6049 - val_sensitivity: 0.4433 - val_specificity: 0.9038 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3994
# Epoch 31/50
# 249/249 [==============================] - 88s 352ms/step - loss: 0.5311 - accuracy: 0.9907 - mean_io_u_24: 0.9140 - dice_coef: 0.4809 - precision: 0.6575 - sensitivity: 0.4515 - specificity: 0.9145 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4142 - val_loss: 0.5638 - val_accuracy: 0.9908 - val_mean_io_u_24: 0.8492 - val_dice_coef: 0.4490 - val_precision: 0.6038 - val_sensitivity: 0.4197 - val_specificity: 0.8911 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3927
# Epoch 32/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5313 - accuracy: 0.9904 - mean_io_u_24: 0.8984 - dice_coef: 0.4814 - precision: 0.6601 - sensitivity: 0.4495 - specificity: 0.9069 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4166 - val_loss: 0.6181 - val_accuracy: 0.9901 - val_mean_io_u_24: 0.9525 - val_dice_coef: 0.3982 - val_precision: 0.5846 - val_sensitivity: 0.3706 - val_specificity: 0.8581 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3535
# Epoch 33/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5102 - accuracy: 0.9909 - mean_io_u_24: 0.9237 - dice_coef: 0.5012 - precision: 0.6805 - sensitivity: 0.4700 - specificity: 0.9224 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4313 - val_loss: 0.5339 - val_accuracy: 0.9918 - val_mean_io_u_24: 0.9120 - val_dice_coef: 0.4766 - val_precision: 0.6442 - val_sensitivity: 0.4505 - val_specificity: 0.9157 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4156
# Epoch 34/50
# 249/249 [==============================] - 88s 352ms/step - loss: 0.4962 - accuracy: 0.9913 - mean_io_u_24: 0.9285 - dice_coef: 0.5147 - precision: 0.6832 - sensitivity: 0.4860 - specificity: 0.9276 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4421 - val_loss: 0.5093 - val_accuracy: 0.9920 - val_mean_io_u_24: 0.9314 - val_dice_coef: 0.5015 - val_precision: 0.6543 - val_sensitivity: 0.4883 - val_specificity: 0.9204 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4365
# Epoch 35/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.5044 - accuracy: 0.9909 - mean_io_u_24: 0.9160 - dice_coef: 0.5078 - precision: 0.6808 - sensitivity: 0.4775 - specificity: 0.9209 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4368 - val_loss: 0.5616 - val_accuracy: 0.9907 - val_mean_io_u_24: 0.8880 - val_dice_coef: 0.4510 - val_precision: 0.6447 - val_sensitivity: 0.4280 - val_specificity: 0.8818 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3951
# Epoch 36/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.5050 - accuracy: 0.9912 - mean_io_u_24: 0.9246 - dice_coef: 0.5061 - precision: 0.6716 - sensitivity: 0.4807 - specificity: 0.9233 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4350 - val_loss: 0.4934 - val_accuracy: 0.9923 - val_mean_io_u_24: 0.9269 - val_dice_coef: 0.5170 - val_precision: 0.6517 - val_sensitivity: 0.5071 - val_specificity: 0.9413 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.4492
# Epoch 37/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.4864 - accuracy: 0.9915 - mean_io_u_24: 0.9280 - dice_coef: 0.5245 - precision: 0.6956 - sensitivity: 0.4946 - specificity: 0.9305 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4514 - val_loss: 0.6426 - val_accuracy: 0.9894 - val_mean_io_u_24: 0.9437 - val_dice_coef: 0.3777 - val_precision: 0.5690 - val_sensitivity: 0.3472 - val_specificity: 0.8366 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3366
# Epoch 38/50
# 249/249 [==============================] - 88s 351ms/step - loss: 0.5375 - accuracy: 0.9903 - mean_io_u_24: 0.9187 - dice_coef: 0.4751 - precision: 0.6598 - sensitivity: 0.4468 - specificity: 0.9103 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4107 - val_loss: 0.4935 - val_accuracy: 0.9921 - val_mean_io_u_24: 0.9157 - val_dice_coef: 0.5172 - val_precision: 0.6591 - val_sensitivity: 0.5264 - val_specificity: 0.9443 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4489
# Epoch 39/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.4809 - accuracy: 0.9915 - mean_io_u_24: 0.9286 - dice_coef: 0.5297 - precision: 0.6969 - sensitivity: 0.5007 - specificity: 0.9309 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4558 - val_loss: 0.4959 - val_accuracy: 0.9921 - val_mean_io_u_24: 0.9198 - val_dice_coef: 0.5145 - val_precision: 0.6439 - val_sensitivity: 0.5043 - val_specificity: 0.9248 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.4468
# Epoch 40/50
# 249/249 [==============================] - 88s 355ms/step - loss: 0.4705 - accuracy: 0.9919 - mean_io_u_24: 0.9373 - dice_coef: 0.5395 - precision: 0.7025 - sensitivity: 0.5122 - specificity: 0.9386 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4625 - val_loss: 0.4992 - val_accuracy: 0.9921 - val_mean_io_u_24: 0.9386 - val_dice_coef: 0.5113 - val_precision: 0.6597 - val_sensitivity: 0.4844 - val_specificity: 0.9219 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4446
# Epoch 41/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.4863 - accuracy: 0.9915 - mean_io_u_24: 0.9276 - dice_coef: 0.5246 - precision: 0.6878 - sensitivity: 0.4942 - specificity: 0.9298 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4504 - val_loss: 0.4749 - val_accuracy: 0.9919 - val_mean_io_u_24: 0.9205 - val_dice_coef: 0.5361 - val_precision: 0.6898 - val_sensitivity: 0.5198 - val_specificity: 0.9503 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 0.9999 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.4558
# Epoch 42/50
# 249/249 [==============================] - 88s 352ms/step - loss: 0.4859 - accuracy: 0.9915 - mean_io_u_24: 0.9263 - dice_coef: 0.5250 - precision: 0.6851 - sensitivity: 0.4948 - specificity: 0.9285 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4508 - val_loss: 0.4981 - val_accuracy: 0.9920 - val_mean_io_u_24: 0.9301 - val_dice_coef: 0.5133 - val_precision: 0.6557 - val_sensitivity: 0.5004 - val_specificity: 0.9246 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 0.9999 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.4435
# Epoch 43/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.4733 - accuracy: 0.9918 - mean_io_u_24: 0.9364 - dice_coef: 0.5369 - precision: 0.6862 - sensitivity: 0.5161 - specificity: 0.9375 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4612 - val_loss: 0.4788 - val_accuracy: 0.9923 - val_mean_io_u_24: 0.9228 - val_dice_coef: 0.5318 - val_precision: 0.6574 - val_sensitivity: 0.5274 - val_specificity: 0.9481 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4590
# Epoch 44/50
# 249/249 [==============================] - 88s 355ms/step - loss: 0.4648 - accuracy: 0.9919 - mean_io_u_24: 0.9290 - dice_coef: 0.5453 - precision: 0.7011 - sensitivity: 0.5186 - specificity: 0.9382 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4667 - val_loss: 0.4978 - val_accuracy: 0.9920 - val_mean_io_u_24: 0.9343 - val_dice_coef: 0.5131 - val_precision: 0.6623 - val_sensitivity: 0.4875 - val_specificity: 0.9114 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4441
# Epoch 45/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.4811 - accuracy: 0.9915 - mean_io_u_24: 0.9269 - dice_coef: 0.5295 - precision: 0.6947 - sensitivity: 0.5111 - specificity: 0.9334 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4547 - val_loss: 0.4886 - val_accuracy: 0.9924 - val_mean_io_u_24: 0.9564 - val_dice_coef: 0.5217 - val_precision: 0.6606 - val_sensitivity: 0.5087 - val_specificity: 0.9269 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4534
# Epoch 46/50
# 249/249 [==============================] - 89s 355ms/step - loss: 0.4480 - accuracy: 0.9924 - mean_io_u_24: 0.9458 - dice_coef: 0.5613 - precision: 0.7130 - sensitivity: 0.5414 - specificity: 0.9445 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4814 - val_loss: 0.4741 - val_accuracy: 0.9924 - val_mean_io_u_24: 0.9297 - val_dice_coef: 0.5359 - val_precision: 0.6836 - val_sensitivity: 0.5175 - val_specificity: 0.9406 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4629
# Epoch 47/50
# 249/249 [==============================] - 88s 354ms/step - loss: 0.4439 - accuracy: 0.9924 - mean_io_u_24: 0.9456 - dice_coef: 0.5653 - precision: 0.7161 - sensitivity: 0.5393 - specificity: 0.9476 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4830 - val_loss: 0.4615 - val_accuracy: 0.9926 - val_mean_io_u_24: 0.9694 - val_dice_coef: 0.5498 - val_precision: 0.7090 - val_sensitivity: 0.5335 - val_specificity: 0.9411 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4726
# Epoch 48/50
# 249/249 [==============================] - 88s 355ms/step - loss: 0.4447 - accuracy: 0.9924 - mean_io_u_24: 0.9434 - dice_coef: 0.5646 - precision: 0.7204 - sensitivity: 0.5390 - specificity: 0.9458 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4835 - val_loss: 0.5278 - val_accuracy: 0.9915 - val_mean_io_u_24: 0.9551 - val_dice_coef: 0.4899 - val_precision: 0.6765 - val_sensitivity: 0.4770 - val_specificity: 0.9006 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4267
# Epoch 49/50
# 249/249 [==============================] - 88s 353ms/step - loss: 0.4558 - accuracy: 0.9922 - mean_io_u_24: 0.9293 - dice_coef: 0.5542 - precision: 0.7016 - sensitivity: 0.5278 - specificity: 0.9393 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4755 - val_loss: 0.4710 - val_accuracy: 0.9925 - val_mean_io_u_24: 0.9377 - val_dice_coef: 0.5392 - val_precision: 0.6919 - val_sensitivity: 0.5280 - val_specificity: 0.9379 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4664
# Epoch 50/50
# 249/249 [==============================] - 89s 357ms/step - loss: 0.4575 - accuracy: 0.9920 - mean_io_u_24: 0.9326 - dice_coef: 0.5524 - precision: 0.7098 - sensitivity: 0.5314 - specificity: 0.9411 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4721 - val_loss: 0.5321 - val_accuracy: 0.9919 - val_mean_io_u_24: 0.9422 - val_dice_coef: 0.4797 - val_precision: 0.6681 - val_sensitivity: 0.4635 - val_specificity: 0.9189 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4191

# %%
model.save("model_my_3Dplus_UNet.h5")

# %%
############ load trained model ################
model = tf.keras.models.load_model(
    '/kaggle/working/model_my_3Dplus_UNet.h5',
    custom_objects={
        'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=4),  # Use 'MeanIoU' instead of 'accuracy'
        'dice_coef': dice_coef,
        'precision': precision,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'dice_coef_necrotic': dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core (class 0)
        'dice_coef_edema': dice_coef_per_class(1, "dice_coef_edema"),         # Peritumoral Edema (class 1)
        'dice_coef_enhancing': dice_coef_per_class(2, "dice_coef_enhancing")  # Enhancing Tumor (class 2)
    },
    compile=False  # Do not compile the model during loading
)


############### ########## ####### #######

hist=history.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u_24'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u_24'],'r',label='Validation mean IOU')
ax[3].legend()
plt.savefig('training_result_2018.png')
plt.show()

# %%
model = tf.keras.models.load_model(
    '/kaggle/working/model_my_3Dplus_UNet.h5',
    custom_objects={
        'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=4),  # Use 'MeanIoU' instead of 'accuracy'
        'dice_coef': dice_coef,
        'precision': precision,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'dice_coef_necrotic': dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core (class 0)
        'dice_coef_edema': dice_coef_per_class(1, "dice_coef_edema"),         # Peritumoral Edema (class 1)
        'dice_coef_enhancing': dice_coef_per_class(2, "dice_coef_enhancing")  # Enhancing Tumor (class 2)
    },
    compile=False  # Do not compile the model during loading
)
model.compile(
    loss=bce_dice_loss,  # Use your custom loss function
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core
        dice_coef_per_class(1, "dice_coef_edema"),     # Peritumoral Edema
        dice_coef_per_class(2, "dice_coef_enhancing"), # Enhancing Tumor
        jaccard_coef
    ]
)
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(my_test_generator, batch_size=100)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 45/45 [==============================] - 9s 172ms/step - loss: 0.5055 - accuracy: 0.9919 - mean_io_u_34: 0.9438 - dice_coef: 0.5042 - precision: 0.6997 - sensitivity: 0.4923 - specificity: 0.9393 - dice_coef_necrotic: 0.9997 - dice_coef_edema: 0.9996 - dice_coef_enhancing: 0.9993 - jaccard_coef: 0.4368
# test loss, test acc: [0.5055212378501892, 0.9919438362121582, 0.9438138008117676, 0.5041604042053223, 0.6997310519218445, 0.49227914214134216, 0.9393186569213867, 0.9996981024742126, 0.9995596408843994, 0.9992637038230896, 0.43680301308631897]

# %%
# DataGenerator(ex: test_generator)=>tuple(images,mask)
# images=>[slice,depth,width,height,channels]
# mask=>[slice,depth,width,height,labels]

img_num = 33
test_img = test_generator.__getitem__(img_num)[0]    #tuple(image,mask) -> 0: image
test_mask = test_generator.__getitem__(img_num)[1]   #tuple(image,mask) -> 1: mask
test_mask_argmax=np.argmax(test_mask, axis=4)[0,:,:,:]

test_prediction = model.predict(test_img)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

print("test_prediction_shape: " + str(test_prediction.shape))
print("test_prediction_argmax_shape: " + str(test_prediction_argmax.shape))
print(np.unique(test_prediction_argmax))
print("test_img_shape: " + str(test_img.shape))
print("test_mask_shape: " + str(test_mask.shape))
print("test_mask_argmax: " + str(test_mask_argmax.shape))

n_slice = 15
for n_slice in range(48):
    plt.figure(figsize=(12, 8))
    plt.subplot(231)
    plt.title('Testing Image')
    plt.imshow(test_img[0,:,:,n_slice,0], cmap='gray')
    plt.subplot(232)
    plt.title('Testing Label')
    plt.imshow(test_mask_argmax[:,:,n_slice])
    plt.subplot(233)
    plt.title('Prediction on test image')
    plt.imshow(test_prediction_argmax[:,:,n_slice])
    plt.show()
# Out:
# test_prediction_shape: (1, 128, 128, 48, 4)
# test_prediction_argmax_shape: (128, 128, 48)
# [0 1 2 3]
# test_img_shape: (1, 128, 128, 48, 3)
# test_mask_shape: (1, 128, 128, 48, 4)
# test_mask_argmax: (128, 128, 48)

# %%
import matplotlib.pyplot as plt

img_num = 15
test_img = test_generator.__getitem__(img_num)[0]    #tuple(image,mask) -> 0: image
test_mask = test_generator.__getitem__(img_num)[1]   #tuple(image,mask) -> 1: mask
test_mask_argmax=np.argmax(test_mask, axis=4)[0,:,:,:]

test_prediction = model.predict(test_img)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

print("test_prediction_shape: " + str(test_prediction.shape))
print("test_prediction_argmax_shape: " + str(test_prediction_argmax.shape))
print(np.unique(test_prediction_argmax))
print("test_img_shape: " + str(test_img.shape))
print("test_mask_shape: " + str(test_mask.shape))
print("test_mask_argmax: " + str(test_mask_argmax.shape))

slice_index = 15

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,slice_index,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,slice_index])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:,slice_index])
plt.show()
# Out:
# test_prediction_shape: (1, 128, 128, 48, 4)
# test_prediction_argmax_shape: (128, 128, 48)
# [0 1 2]
# test_img_shape: (1, 128, 128, 48, 3)
# test_mask_shape: (1, 128, 128, 48, 4)
# test_mask_argmax: (128, 128, 48)
